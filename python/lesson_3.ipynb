# %%
if door_is_closed: # возвращает True or False (Булево значение) по умолчанию, под капотом door_is_closed == True
    if door_is_locked:
        unlock_door()
    open_door()
advance()

# %%
if door_is_closed:
    if door_is_locked:
        unlock_door()
    open_door()
advance()

# %%
import keyword
dir(keyword.kwlist) # cmd + click == help, место инициализации, dir дает список идентификаторов # получаем свойства и методы обьекта
#x = int(input())
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
number = 1
number_2 = 2
print("Итого", number + number_2, sep="=") #  Переобреление параметра сепаратора
print(number.__add__(number_2))


# 3 и 4 строки эквивалентны, всегда вызываются магические методы под капотом
# Out:
# Итого=3
# 3

# %%
print(number_2.__sub__(number))
# Out:
# 1

# %%
help(keyword.kwlist) # cmd + click == help, место инициализации, dir дает список идентификаторов # получаем свойства и методы обьекта
#x = int(input())
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
text = "Hello world!"
number = 15
print(type(text))
print(type(number))
dir(text)
#help(str)
print(text.upper())
# Out:
# <class 'str'>
# <class 'int'>
# HELLO WORLD!

# %% [markdown]
# ## Все В Python является обьектом, у обьектов есть свойства и методы
# ## функция type показывает какого типа является обьект
# ##

# %%
print(type(keyword.kwlist))
dir(keyword.kwlist)
help(keyword.kwlist)
list.append()
# Out:
# <class 'list'>
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
spisok = []
print(spisok.append("senatorov"))
print(spisok)
# Out:
# None
# ['senatorov']

# %% [markdown]
# ## По умолчанию функция возвращает тип данных None, если мы не пишем функцию return
